# %%
#The scedule for start program
def start():
    print("Supermarket Management System ")
    print("="*30)
    print(" 1. Print items info","\n","2. Search for an item ","\n","3. Add new item ","\n","4. Remove an item","\n","5. Sell an item","\n",
    "6. Update an item","\n","7. Exit ")
    print("="*30,"\n")
################################################################################################################################
# fun main to include all fun in the program.
def main ():
    infile = open("itemsInfo.txt","r")
    dic = {}
    for key in infile:
        x = key.split(",")
        a = int(x[0])
        b = x[1] 
        dic[a] = [x[1],float(x[2]),int(x[3]),int(x[4])]
    infile.close()     
#######################
    start()
    choice = input("Enter your choice: ")
    ########################################################################################
    while choice :
        if int(choice) == 1 :
            print_items(dic)
            start()
            choice = input("Enter your choice: ")

   #########################################################################################     
        elif int(choice) == 2 :        
            searchitem(dic)
            start()
            choice = input("Enter your choice: ")
        
   #########################################################################################
        elif int(choice) == 3 :
            add_item(dic)
            start()
            choice = input("Enter your choice: ")
           
   #########################################################################################           
        elif int(choice) == 4 :
            remove_item(dic)
            start()
            choice = input("Enter your choice: ")
            
  ##########################################################################################  
        elif int(choice) == 5 :
            sell_item(dic)
            start()
            choice = input("Enter your choice: ")
            
  ###########################################################################################   
        elif int(choice) == 6 :
            Update_an_item(dic)
            start()
            choice = input("Enter your choice: ")
   ###########################################################################################
        elif int(choice) == 7 :
            outfile = open("Items_Info.txt","w")
            for Key in dic :
                lista = dic[Key]
                outfile.write(str(Key))
                outfile.write(",")
                outfile.write(lista[0])
                outfile.write(",")
                outfile.write(str(lista[1]))
                outfile.write(",") 
                outfile.write(str(lista[2]))
                outfile.write(",")   
                outfile.write(str(lista[3]))
                outfile.write("\n")  
            outfile.close()

################################################################################################################################
#fun to print the scedule.
def print_items(dic):
        print("%-8s %-15s %30s %18s" % ("SN","Item Name","Price","Total Items"))
        for Key in dic:
            x = dic[Key]
            print("%-8s %-15s %30s %18s" % (Key,x[0],x[1],x[2]))
      ###########################################################################################################
# fun to search about the item
def searchitem(dic):
    print("1. By Serial Number")
    print("2. By Item Name ")
    choice2 = input("Enter your choice:")   
    if int(choice2) == 1 : 
        serial_num = int(input("Enter serial number of the item:"))
        if serial_num in dic :
            print("%-8s %-15s %10s %20s %18s" % ("SN","Item Name","Price","Available Items","Sold Items"))
            for Key in dic :
                x = dic[Key]
                if serial_num == Key : 
                    print("%-8s %-15s %10s %20s %18s" % (Key,x[0],x[1],x[2],x[3]))
        elif serial_num not in dic :
            print("Item does not exist")
                    #####################################################           
    elif  int(choice2) == 2 :
        item_name = input("Enter item name or part of it:")
        print("%-8s %-15s %10s %20s %18s" % ("SN","Item Name","Price","Available Items","Sold Items"))        
        for Key in dic:
            x = dic[Key]
            if item_name.upper() == x[0] or item_name in x[0] :
                print("%-8s %-15s %10s %20s %18s" % (Key,x[0],x[1],x[2],x[3]))
    #file()
    ###############################################################################################################
#دالة لإضافة عناصر جديدة عل الجدول 
def add_item(dic) :
    sn = int(input("Enter item SN: "))
    while sn :
        if sn in dic.keys() :
            print("Serial Number already exists")
            sn = input("Enter item SN: ")
        if int(sn) not in dic.keys() :
            name = input("Enter item name: ")
            if name == "" or name in dic.values() :
                print("Item name cannot be empty")
                name = input("Enter item name: ")
            if (name != "" )or (name not in dic.values()) :    
                price = input("Enter item price: ")
                if price != "":
                    price2 = float(price)
                    number = input("Enter number of available items: ")
                    if number != "":
                        number = float(number)
                        if int(number) > 0 :
                            item_sells = 0 
                            dic[sn]= (name , price, number,item_sells)
                    if number == "" :
                        number = input("Enter number of available items: ")
                        if number != "":
                            number = float(number)
                        if int(number) > 0 :
                            item_sells = 0 
                            dic[sn]= (name , price, number,item_sells)
                    if number <= 0 :
                        number = input("Enter number of available items: ")
                        if number != "":
                            number = float(number)
                        if int(number) > 0 :
                            item_sells = 0 
                            dic[sn]= (name , price, number,item_sells)                                               
                    
                    
                    if price2 == "" :
                        print("Price must be a positive value and non-empty")
                        price = input("Enter item price: ")
                        number = input("Enter number of available items: ")
                        if number != "":
                            number = float(number)
                        if int(number) > 0 :
                            item_sells = 0 
                            dic[sn]= (name , price, number,item_sells)
                    if number == "" :
                        number = input("Enter number of available items: ")
                        if number != "":
                            number = float(number)
                        if int(number) > 0 :
                            item_sells = 0 
                            dic[sn]= (name , price, number,item_sells)
                    if number <= 0 :
                        number = input("Enter number of available items: ")
                        if number != "":
                            number = float(number)
                        if int(number) > 0 :
                            item_sells = 0 
                            dic[sn]= (name , price, number,item_sells)     
                        
                        
                if price == "":
                    print("Price must be a positive value and non-empty")
                    price = input("Enter item price: ")
                    number = input("Enter number of available items: ")
                    if number != "":
                        number = float(number)
                        if int(number) > 0 :
                            item_sells = 0 
                            dic[sn]= (name , price, number,item_sells)
                    if number == "" :
                        number = input("Enter number of available items: ")
                        if number != "":
                            number = float(number)
                        if int(number) > 0 :
                            item_sells = 0 
                            dic[sn]= (name , price, number,item_sells)
                    if number <= 0 :
                        number = input("Enter number of available items: ")
                        if number != "":
                            number = float(number)
                        if int(number) > 0 :
                            item_sells = 0 
                            dic[sn]= (name , price, number,item_sells)     
            break            

    print("Item has been added successfully !!!")
    ###############################################################################################################
# دالة لحذف عناصر معينة من الفايل من خلا تحديد رقمها التسلسلي
def remove_item(dic):    
    serial_num2 = int(input("Enter serial number of the item: "))
    if serial_num2 not in dic :
        print("Item does not exist")
    else :
        print("%-8s %-15s %10s %20s %18s" % ("SN","Item Name","Price","Available Items","Sold Items"))
        for Key in dic :
            x = dic[Key]
            if serial_num2 == Key : 
                print("%-8s %-15s %10s %20s %18s" % (Key,x[0],x[1],x[2],x[3]))
                     #####################################################
        Yes_No = input("Are you sure you want to remove this item ? [Y/N] ")
        if Yes_No == "y" or Yes_No =="Y":
            dic.pop(serial_num2)
            print("Item has been removed successfully :)")
        elif Yes_No == "n" or Yes_No == "N" :
            print("No item has removed")
        #file()     
    ###############################################################################################################
def sell_item(dic) :
    serial = int(input("Enter serial number of the item: "))
    if serial not in dic.keys() :
        print("Item does not exist")
    else :
        person = input("Enter the name of the person who bought this item: ")
        while dic[serial]:
            val = dic[serial]
            val[3] = int(val[3]) + 1 
            file = open("soldItems.txt" , 'w')
            file.write(str(serial)+",")
            file.write(person)
            file.close()
            break
        print("Item has been sold to "+ person + " Successfully")
     ###############################################################################################################  
def Update_an_item(dic):
    serial_num3 = int(input("Enter serial number of the item: "))
    if serial_num3 not in dic :
        print("Item does not exist")
    else :
        print("1. Name ","\n","2. Available Items ")
        The_update = input("What would you like to update ?")        
        if int(The_update) == 1 :
            name_update = input("Enter the new available name of items: ")            
            while serial_num3 :           
                val = dic[serial_num3]
                val[0] = name_update
                print("Item has been updated successfully :)")
                break
        if int(The_update) == 2 :
            new_number = input("Enter the new available number of items: ")
            while serial_num3 :           
                val = dic[serial_num3]
                val[2] = new_number
                print("Item has been updated successfully :)")
                break
################################################################################################################################
main( )
# Out:
# Supermarket Management System
# ...
#  1. Print items info
#  2. Search for an item
#  3. Add new item
#  4. Remove an item
#  5. Sell an item
#  6. Update an item
#  7. Exit
# ...
#
# Enter your choice: 3
# Enter item SN: 1111
# Enter item name:
# Item name cannot be empty
# Enter item name: Mango
# Enter item price: 19.99
# Enter number of available items: 21
# Item has been added successfully !!!
# Supermarket Management System
# ...
#  1. Print items info
#  2. Search for an item
#  3. Add new item
#  4. Remove an item
#  5. Sell an item
#  6. Update an item
#  7. Exit
# ...
#
# Enter your choice: 3
# Enter item SN: 1111
# Serial Number already exists
# Enter item SN: 2222
# Enter item name:
# Item name cannot be empty
# Enter item name: Kiwi
# Enter item price:
# Price must be a positive value and non-empty
# Enter item price: -4
# Enter number of available items: 21
# Item has been added successfully !!!
# Supermarket Management System
# ...
#  1. Print items info
#  2. Search for an item
# ...
